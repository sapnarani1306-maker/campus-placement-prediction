# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("studentcsv.dataset.csv")
df.head()
# Out:
#    Age Gender College_Tier    Specialization  CGPA  DSA_Problems_Solved  \
# 0   19   Male       Tier 3             AI/ML  7.70                  229
# 1   21  Other       Tier 3             Civil  6.97                  486
# 2   20  Other       Tier 2       Electronics  6.74                  180
# 3   18  Other       Tier 2  Computer Science  6.64                   98
# 4   18  Other       Tier 2       Electronics  8.67                  216
#
#    Internships  Certifications  Projects_Count  Communication_Skills
# 0            0               1              11                    87
# 1            0              10              12                    74
# 2            0               5               2                    45
# 3            4               6               2                    75
# 4            4               3               2                    64

# %%
df.info
# Out:
# <bound method DataFrame.info of        Age  Gender College_Tier    Specialization  CGPA  DSA_Problems_Solved  \
# 0       19    Male       Tier 3             AI/ML  7.70                  229
# 1       21   Other       Tier 3             Civil  6.97                  486
# 2       20   Other       Tier 2       Electronics  6.74                  180
# 3       18   Other       Tier 2  Computer Science  6.64                   98
# 4       18   Other       Tier 2       Electronics  8.67                  216
# ...    ...     ...          ...               ...   ...                  ...
# 19995   19  Female       Tier 3      Data Science  7.55                    0
# 19996   22    Male       Tier 3             AI/ML  8.13                  116
# 19997   25   Other       Tier 1       Electronics  7.64                  172
# 19998   18  Female       Tier 2      Data Science  7.84                  373
# 19999   20    Male       Tier 1             AI/ML  6.97                  164
#
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of        Age  Gender College_Tier    Specialization  CGPA  DSA_Problems_Solved  \
# 0       19    Male       Tier 3             AI/ML  7.70                  229
# 1       21   Other       Tier 3             Civil  6.97                  486
# 2       20   Other       Tier 2       Electronics  6.74                  180
# 3       18   Other       Tier 2  Computer Science  6.64                   98
# 4       18   Other       Tier 2       Electronics  8.67                  216
# ...    ...     ...          ...               ...   ...                  ...
# 19995   19  Female       Tier 3      Data Science  7.55                    0
# 19996   22    Male       Tier 3             AI/ML  8.13                  116
# 19997   25   Other       Tier 1       Electronics  7.64                  172
# 19998   18  Female       Tier 2      Data Science  7.84                  373
# 19999   20    Male       Tier 1             AI/ML  6.97                  164
#
# ...

# %%
df.describe()
# Out:
#                 Age          CGPA  DSA_Problems_Solved   Internships  \
# count  20000.000000  20000.000000         20000.000000  20000.000000
# mean      21.506600      7.202949           253.263700      1.450200
# std        2.295347      1.005041           144.140893      1.160296
# min       18.000000      4.500000             0.000000      0.000000
# 25%       19.000000      6.520000           150.000000      0.000000
# 50%       22.000000      7.210000           249.500000      1.000000
# 75%       24.000000      7.880000           352.000000      2.000000
# max       25.000000     10.000000           841.000000      4.000000
#
#        Certifications  Projects_Count  Communication_Skills
# count     20000.00000    20000.000000           20000.00000
# mean          5.01255        6.503900              70.15475
# std           3.14957        3.437932              17.70118
# min           0.00000        1.000000              40.00000
# ...

# %%
df.sample()
# Out:
#       Age Gender College_Tier Specialization  CGPA  DSA_Problems_Solved  \
# 8729   23  Other       Tier 1     Mechanical  6.47                  135
#
#       Internships  Certifications  Projects_Count  Communication_Skills
# 8729            2               7               1                    50

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'College_Tier', 'Specialization', 'CGPA',
#        'DSA_Problems_Solved', 'Internships', 'Certifications',
#        'Projects_Count', 'Communication_Skills'],
#       dtype='object')

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19995    False
# 19996    False
# 19997    False
# 19998    False
# 19999    False
# Length: 20000, dtype: bool

# %%
df["Age"].max()
# Out:
# 25

# %%
df.isnull().sum()
# Out:
# Age                     0
# Gender                  0
# College_Tier            0
# Specialization          0
# CGPA                    0
# DSA_Problems_Solved     0
# Internships             0
# Certifications          0
# Projects_Count          0
# Communication_Skills    0
# dtype: int64

# %%
 df.notnull()
# Out:
#         Age  Gender  College_Tier  Specialization  CGPA  DSA_Problems_Solved  \
# 0      True    True          True            True  True                 True
# 1      True    True          True            True  True                 True
# 2      True    True          True            True  True                 True
# 3      True    True          True            True  True                 True
# 4      True    True          True            True  True                 True
# ...     ...     ...           ...             ...   ...                  ...
# 19995  True    True          True            True  True                 True
# 19996  True    True          True            True  True                 True
# 19997  True    True          True            True  True                 True
# 19998  True    True          True            True  True                 True
# 19999  True    True          True            True  True                 True
#
# ...

# %%
df.sample(10)
# Out:
#        Age  Gender College_Tier          Specialization  CGPA  \
# 6495    21   Other       Tier 1        Computer Science  8.40
# 8730    20  Female       Tier 2                   AI/ML  4.50
# 3271    18    Male       Tier 1             Electronics  7.15
# 11873   25   Other       Tier 3  Information Technology  6.86
# 12375   22   Other       Tier 3                   Civil  5.83
# 2615    23  Female       Tier 1        Computer Science  6.56
# 7475    25  Female       Tier 3                   AI/ML  7.27
# 8448    20    Male       Tier 2                   Civil  7.70
# 15911   24    Male       Tier 3             Electronics  8.71
# 9042    19   Other       Tier 2             Electronics  7.68
#
#        DSA_Problems_Solved  Internships  Certifications  Projects_Count  \
# 6495                   158            0               8               1
# 8730                     0            0               4               9
# ...

# %%
plt.plot(df.groupby("Projects_Count")["CGPA"].mean(), marker='o')
plt.xlabel("Projects")
plt.ylabel("CGPA")
plt.show()

# %%
df['Gender'].value_counts().plot(kind='pie',autopct='%f%%')
plt.show()

# %%
df['Specialization'].value_counts().plot(kind='bar',color='teal')
plt.show()

# %%
df['College_Tier'].value_counts().plot(kind='bar',color='blue')
plt.show()

# %%
df['Certifications'].value_counts().plot(kind='pie',color='teal',autopct='%f%%')
plt.show()
